# %%
import pandas as pd

# %%
df = pd.read_csv("Biker_test_filtered.csv")
# df_title = df["title"].to_list()

# %%
import json 

with open('verbList.json') as f:
    data = json.load(f)

# %%
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0      How to convert binary string value to decimal
# 1             1  How can I use html styles in strings with form...
# 2             2  Converting a sentence string to a string array...
# 3             3  How do I create a parent-last / child-first Cl...
# 4             4  How to modify a Collection while iterating usi...
# ..          ...                                                ...
# 258         258     Loading XML File which is in classpath in Java
# 259         259  How to call Collections.Shuffle on only part o...
# 260         260                 Reopen database connection in Java
# 261         261  Java - Is it possible to add a JMenuBar to a J...
# 262         262                        TimeZone validation in Java
#
#                                                 answer
# 0                       ['java.lang.Integer.parseInt']
# ...

# %%
import spacy
import re

nlp = spacy.load("en_core_web_sm")
res_pat_list=[]
relation_list=[]
for index, row in df.iterrows():
    text = row['title'].split(" ")
    
    doc=nlp(text)
    
    for token in doc:
        if token.text = 
    is_stop = eval(row['is_stop'])
    flag=0
    pat_list=[]
#     print(text)
#     print(len(text))
    for idx,token in enumerate(text):
#         print(text[idx])
        if text[idx] in res:
            pat_list.append(token)
            flag=1
        elif is_stop[idx]:
            pat_list.append(token)
    if flag==1:
        print(text)
        print(pat_list)
        res_pat_list.append(pat_list)
